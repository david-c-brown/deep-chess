# %%
import chess
import numpy as np
import concurrent.futures
import time
from IPython.display import clear_output

from mcts import mcts
from nn import *

# %%
# Create chess board and get input tensor
board = chess.Board()
input_tensor = board_to_input(board)

chess_model = create_chess_model()
chess_model.summary()
chess_model.evaluate = evaluate.__get__(chess_model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 8, 8, 12)]   0           []
#
#  conv2d (Conv2D)                (None, 8, 8, 256)    27904       ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 8, 8, 256)   1024        ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 8, 8, 256)    590080      ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu (ReLU)                   (None, 8, 8, 256)    0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 8, 8, 256)    590080      ['re_lu[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 8, 8, 256)    0           ['batch_normalization[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 8, 8, 256)    0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 256)    590080      ['re_lu_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_3[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 8, 8, 256)    0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 8, 8, 256)    590080      ['re_lu_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 8, 8, 256)    0           ['re_lu_1[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 8, 8, 256)    0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 256)    590080      ['re_lu_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 8, 8, 256)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 256)    590080      ['re_lu_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 8, 8, 256)    0           ['re_lu_3[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 8, 8, 256)    0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 256)    590080      ['re_lu_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 8, 8, 256)    0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    590080      ['re_lu_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 8, 8, 256)    0           ['re_lu_5[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 8, 8, 256)    0           ['add_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['re_lu_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 8, 8, 256)    0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_10[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 8, 8, 256)    0           ['re_lu_7[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 8, 8, 256)    0           ['add_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_12[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 8, 8, 256)    0           ['re_lu_9[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  re_lu_11 (ReLU)                (None, 8, 8, 256)    0           ['add_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_11[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_14[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 8, 8, 256)    0           ['re_lu_11[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  re_lu_13 (ReLU)                (None, 8, 8, 256)    0           ['add_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_15[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 8, 8, 256)    0           ['re_lu_13[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  re_lu_15 (ReLU)                (None, 8, 8, 256)    0           ['add_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_17[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_16[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_18[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 8, 8, 256)    0           ['re_lu_15[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  re_lu_17 (ReLU)                (None, 8, 8, 256)    0           ['add_8[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_17[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_19[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_18[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_20[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 8, 8, 256)    0           ['re_lu_17[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  re_lu_19 (ReLU)                (None, 8, 8, 256)    0           ['add_9[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_19[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_21[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_20[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_22[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 8, 8, 256)    0           ['re_lu_19[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  re_lu_21 (ReLU)                (None, 8, 8, 256)    0           ['add_10[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_21[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_23[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_22[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_24[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 8, 8, 256)    0           ['re_lu_21[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  re_lu_23 (ReLU)                (None, 8, 8, 256)    0           ['add_11[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_23[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_24[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_26[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 8, 8, 256)    0           ['re_lu_23[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  re_lu_25 (ReLU)                (None, 8, 8, 256)    0           ['add_12[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_25[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_26[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 8, 8, 256)    0           ['re_lu_25[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  re_lu_27 (ReLU)                (None, 8, 8, 256)    0           ['add_13[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_27[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_28[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_30[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 8, 8, 256)    0           ['re_lu_27[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  re_lu_29 (ReLU)                (None, 8, 8, 256)    0           ['add_14[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_29[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_30[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_32[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 8, 8, 256)    0           ['re_lu_29[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  re_lu_31 (ReLU)                (None, 8, 8, 256)    0           ['add_15[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_31[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_33[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_32[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_34[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 8, 8, 256)    0           ['re_lu_31[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  re_lu_33 (ReLU)                (None, 8, 8, 256)    0           ['add_16[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_33[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_35[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_34[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_36[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 8, 8, 256)    0           ['re_lu_33[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  re_lu_35 (ReLU)                (None, 8, 8, 256)    0           ['add_17[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_35[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 256)    590080      ['re_lu_36[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_38[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 8, 8, 256)    0           ['re_lu_35[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  re_lu_37 (ReLU)                (None, 8, 8, 256)    0           ['add_18[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 2)      514         ['re_lu_37[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 1)      257         ['re_lu_37[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 8, 2)     8           ['conv2d_39[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 8, 8, 1)     4           ['conv2d_40[0][0]']
#  ormalization)
#
#  flatten (Flatten)              (None, 128)          0           ['batch_normalization_39[0][0]']
#
#  flatten_1 (Flatten)            (None, 64)           0           ['batch_normalization_40[0][0]']
#
#  dense (Dense)                  (None, 4672)         602688      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 1)            65          ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 23,094,416
# Trainable params: 23,074,442
# Non-trainable params: 19,974
# __________________________________________________________________________________________________

# %%
# Create separate models for black and white players
white_chess_model = create_chess_model()
black_chess_model = create_chess_model()

white_weights_file = "/content/drive/MyDrive/deep_chess/weights/white_chess_model_weights.h5"
black_weights_file = "/content/drive/MyDrive/deep_chess/weights/black_chess_model_weights.h5"

try:
    # Try loading the saved weights for the white and black models
    white_chess_model.load_weights(white_weights_file)
    black_chess_model.load_weights(black_weights_file)
except:
    # If the weights file does not exist, do nothing
    pass

# Define the optimizer and loss functions for the chess models
optimizer = 'adam'
loss = 'categorical_crossentropy'

# Compile the models with the defined optimizer and loss
white_chess_model.compile(optimizer=optimizer, loss=loss)
black_chess_model.compile(optimizer=optimizer, loss=loss)

start_time = time.time()
save_interval = 10

def play_game(game_number, white_model, black_model, num_games, white_score, black_score,draws,num_simulations=100, verbose=False, time_per_move=2):
    board = chess.Board()
    running_reward_sum = 0

    white_rewards = 0
    black_rewards = 0

    while not board.is_game_over():
        if verbose:
            clear_output(wait=True)
            print(f"Game {game_number + 1} out of {num_games}. Reward total: {running_reward_sum}")
            print(f"White wins: {white_score[0]}, {white_rewards} | Black wins: {black_score[0]}, {black_rewards} | Draws: {draws[0]}")
            elapsed_time = (time.time() - start_time)/60
            print(f"Elapsed time: {elapsed_time:.2f}m")
            print(board)

        if board.turn == chess.WHITE:
            move, rewards = mcts(board, white_model, num_simulations=num_simulations)
            white_rewards += rewards
        else:
            move, rewards = mcts(board, black_model, num_simulations=num_simulations)
            black_rewards += rewards
        
        board.push(move)
        running_reward_sum += rewards

    result = board.result()

    return result, white_rewards, black_rewards


def run_multiple_games(white_chess_model, black_chess_model, num_games, num_simulations=100, num_threads=4, time_per_move=2):
    game_results = []
    white_score = [0] 
    black_score = [0]
    draws = [0] 

    white_rewards_list = []
    black_rewards_list = []

    completed_games = 0

    with concurrent.futures.ThreadPoolExecutor(max_workers=num_threads) as executor:
        futures = [executor.submit(play_game, i, white_chess_model, black_chess_model, num_games, white_score, black_score, draws,num_simulations, True, time_per_move) for i in range(num_games)]

        for future in concurrent.futures.as_completed(futures):
            result, white_rewards, black_rewards = future.result()            
            game_results.append(result)
            white_rewards_list.append(white_rewards)
            black_rewards_list.append(black_rewards)

            if result == "1-0":
                white_score[0] += 1  
            elif result == "0-1":
                black_score[0] += 1 
            elif result == "1/2-1/2":
                draws[0] += 1
            
            completed_games += 1
            # Save at steady intervals
            if completed_games % save_interval == 0:
              white_chess_model.save_weights(white_weights_file)
              black_chess_model.save_weights(black_weights_file)
            
    white_rewards_array = np.array(white_rewards_list)
    black_rewards_array = np.array(black_rewards_list)
    results_array = np.array([1 if r == "1-0" else -1 if r == "0-1" else 0 for r in game_results])

    white_rewards_correlation = np.corrcoef(white_rewards_array, results_array)[0, 1]
    black_rewards_correlation = np.corrcoef(black_rewards_array, results_array)[0, 1]

    print(f"Correlation between white rewards and game outcomes: {white_rewards_correlation}")
    print(f"Correlation between black rewards and game outcomes: {black_rewards_correlation}")

    return game_results, white_score[0], black_score[0], draws[0], white_rewards_correlation, black_rewards_correlation

num_games = 50
game_results = run_multiple_games(white_chess_model, black_chess_model, num_games, num_simulations=50, num_threads=2, time_per_move=0.5)

# Save the weights of the trained models
white_chess_model.save_weights(white_weights_file)
black_chess_model.save_weights(white_weights_file)
# Out:
# Game 50 out of 50. Reward total: -4453
# White wins: 0, -2643 | Black wins: 0, -1810 | Draws: 49
# Elapsed time: 96.26m
# r . b q . k n r
# . p p p . p p p
# n . . . . . . .
# p . . . p . . .
# Q . . . . . . P
# b . P P . . . .
# P P . N P P P .
# R . B . K B N R
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2829: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# Correlation between white rewards and game outcomes: nan
# Correlation between black rewards and game outcomes: nan
